# %%
import matplotlib.pyplot as iri 
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)#
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
iri.plot(x,y)

# %%
iri.plot(x,y,'g')
iri.xlabel("linspace array")
iri.ylabel("powers of array")
iri.title("grapr b/w x and y")
# Out:
# Text(0.5, 1.0, 'grapr b/w x and y')

# %%
iri.scatter(x,y,color = "red")
iri.xlabel("linspace array")
iri.ylabel("powers of array")
iri.title("grapr b/w x and y")
# Out:
# Text(0.5, 1.0, 'grapr b/w x and y')

# %%
iri.subplot(2,2,1)
iri.plot(x,y,'g')
iri.subplot(2,2,4)
iri.plot(y,x,'g')
iri.subplot(2,2,2)
iri.scatter(x,y,color = 'orange')
iri.subplot(2,2,3)
iri.scatter(y,x,color = 'blue')

# %%
fig = iri.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axe2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes.plot(x,y,'b')
axe2.scatter(x,y,color = 'red')

# %%
iri.bar(x,y,color = "orange")
# Out:
# <BarContainer object of 11 artists>

# %%
iri.plot(x,y,'r')
iri.scatter(y,x,color = 'black',label = "scatter x/y")
iri.legend()

# %%
iri.plot(x,y)
scale_factor = 2
xmin,xmax = 1,10
ymin,ymar = 2,20
iri.xlim(xmin,xmax)
iri.ylim(ymin,ymax)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-5222183c3315> in <module>
#       4 ymin,ymar = 2,20
#       5 iri.xlim(xmin,xmax)
# ----> 6 iri.ylim(ymin,ymax)
#
# NameError: name 'ymax' is not defined

# %%
xmin
# Out:
# 1

# %%
xmax
# Out:
# 10

# %%
iri.plot(x,y,"r",label = "xvsy")
iri.plot(y,x,"b",label = "yvsx")
iri.plot(x1,y1,'g',label = "x1vsy1")
iri.plot(y1,x1,'orange',label = "y1vsx1")
iri.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-eabebcbbf0d5> in <module>
#       1 iri.plot(x,y,"r",label = "xvsy")
#       2 iri.plot(y,x,"b",label = "yvsx")
# ----> 3 iri.plot(x1,y1,'g',label = "x1vsy1")
#       4 iri.plot(y1,x1,'orange',label = "y1vsx1")
#       5 iri.legend()
#
# NameError: name 'x1' is not defined

# %%
labels = ["phy","python","java","aiml","iot"]
number = [80,120,90,200,300]
iri.pie(number,labels = labels,autopct = "%0.2f%%",colors = ["orange","blue","pink","yellow","purple"])
iri.show()

# %%
iri.figure(figsize = (10,10))
iri.pie(number,labels = labels,autopct = "%0.2f%%",colors = ["orange","blue","pink","yellow","purple"])
iri.show()

# %%
fig =iri.figure(figsize = (10,10))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
ax1.plot(x,y)
ax2.scatter(y,x)
ax3.pie(number,labels = labels,autopct = "%0.2f%%",colors = ["orange","blue","pink","yellow","purple"])
ax4.bar(x,y,color = "purple")
# Out:
# <BarContainer object of 11 artists>

# %%
import seaborn as sns
iri = sns.load_dataset('iris')

# %%
iri
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
sns.scatterplot(x = "sepal_length",y = "sepal_width",data = iri)

# %%
sns.lineplot(x= "petal_length",y= "petal_width",data = iri)

# %%
sns.barplot(x= "sepal_width",y= "petal_width",data = iris)

# %%
sns.boxplot(x= "sepal_length",y= "petal_length",data = iris)

# %%
sns.catplot(x= "petal_length",y= "sepal_length",data = iris)

# %%
sns.pairplot(iris)
